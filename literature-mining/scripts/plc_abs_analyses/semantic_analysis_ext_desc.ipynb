# %% [markdown]
# Uses phase_desc_ext
#
# - Compute semantic similarity between abstracts and phase descriptions (from phase_desc.json)
# - Combine similarity with query-based priors to assign phases
# - Analyze phase distributions and confidence
#
# Results:
# - Semantic phase probabilities are generally low and close together → weak semantic separation
# - Phase 3 (Optimization) becomes dominant for most abstracts when using normal phase_desc.
# - Phase 1 is equally dominant when using extended phase_desc.
# - Query-based priors strongly influence the final phase assignment, since the semantic separation is so weak.
# - The written phase descriptions also becomes too influential.
#
# Regarding the results:
# - This is not necessarily wrong (that most ML-for-manufacturing research focuses on optimization)
# - However, clearer and more detailed phase descriptions are likely needed
# - A bibliometric clustering step should also be introduced before lifecycle phase mapping to reveal natural topic structure in the literature

# %%
# Imports

import json
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm import tqdm
from sentence_transformers import SentenceTransformer
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Paths

data_path = Path("../../data/short-raw-refs-abs")
processed_abstracts_path = Path("../../data/processed/abstracts")
phase_config_path = Path("../../phases/phase_desc_ext.json")
save_path = processed_abstracts_path / "semantic_analysis_ext_desc"


# Ensure directories exist
for p in [data_path, processed_abstracts_path, save_path]:
    p.mkdir(parents=True, exist_ok=True)

print("All directories verified/created.")
# Out:
# All directories verified/created.

# %%
# Load abstracts dataset

abstracts_path = processed_abstracts_path / "abstracts.csv"
df = pd.read_csv(abstracts_path)

print(f"Loaded {len(df)} abstracts from {df['query_id'].nunique()} queries.")
df.head()
# Out:
# Loaded 52290 abstracts from 24 queries.
#                           query_id                  eid  \
# 0  ml_anomaly_detection_production  2-s2.0-105018574505
# 1  ml_anomaly_detection_production  2-s2.0-105019192533
# 2  ml_anomaly_detection_production  2-s2.0-105016669957
# 3  ml_anomaly_detection_production   2-s2.0-85218693791
# 4  ml_anomaly_detection_production  2-s2.0-105018301117
#
#                                  doi  \
# 0  10.1016/j.measurement.2025.119261
# 1       10.1007/978-3-032-06118-8_30
# 2        10.1007/978-3-032-04200-2_5
# 3         10.1038/s41598-025-90810-w
# 4       10.1016/j.comnet.2025.111753
#
#                                                title  \
# 0  Distillation anomaly and fault detection based...
# 1  From Lab to Factory: Pitfalls and Guidelines f...
# 2  Intelligent Defect Detection for Manufacturing...
# 3  Hybrid machine learning framework for predicti...
# 4  BGP anomaly detection using the raw internet t...
#
#                                             abstract  \
# 0  © 2025 The Author(s)The detection of anomalies...
# 1  © The Author(s), under exclusive license to Sp...
# 2  © The Author(s), under exclusive license to Sp...
# 3  © The Author(s) 2025.The critical necessity fo...
# 4  © 2025 The AuthorsThe Border Gateway Protocol ...
#
#                                            clean_abs
# 0  Indeed, highly efficient systems do not always...
# 1  The detection and localization of quality-rela...
# 2  In modern Industry, I4.0, artificial intellige...
# 3  The critical necessity for sophisticated predi...
# 4  Hence, detecting any anomaly concerning BGP an...

# %%
# Count how many rows each query_id has
query_counts = df["query_id"].value_counts().to_dict()

# Create a copy and map the counts to each row
df = df.copy()
df["query_size"] = df["query_id"].map(query_counts)

# Sort so that query groups with fewer rows are prioritized
df_sorted = df.sort_values(by="query_size", ascending=True)

# Remove duplicate DOIs, keeping the one in the smallest query group
df_dedup = df_sorted.drop_duplicates(subset="doi", keep="first").drop(columns=["query_size"])

# Print results
print("Original dataset size:", len(df))
print("After removing duplicates:", len(df_dedup))
print("Remaining duplicate DOIs:", df_dedup["doi"].duplicated().sum())

df = df_dedup
# Out:
# Original dataset size: 52290
# After removing duplicates: 33130
# Remaining duplicate DOIs: 0

# %%
# Load phase descriptions from JSON

with phase_config_path.open("r", encoding="utf-8") as f:
    phases = json.load(f)

phase_ids = list(phases.keys())
phase_texts = [phases[p]["description"] for p in phase_ids]

for pid, ptext in zip(phase_ids, phase_texts):
    print(f"{pid}: {ptext[:80]}...")
# Out:
# phase_1: Research and activities before detailed design or production setup. Focus on def...
# phase_2: Designing products and implementing production systems. Includes detailed engine...
# phase_3: Continuous improvement of established products or production processes using ope...
# phase_4: Focus on products in operation or at end-of-life. Activities include field data ...

# %%
# Phase priors per query_id
# Format: [Phase1_Planning, Phase2_Development/Production, Phase3_Optimization, Phase4_Use/Reuse]

phase_priors = {
    # Use / Reuse — dominant Phase 4
    "ml_inservice_monitoring":       [0.05, 0.20, 0.35, 0.40],
    "ml_remanufacturing":            [0.05, 0.10, 0.15, 0.70],
    "ml_disassembly":                [0.05, 0.25, 0.20, 0.50],
    "ml_end_of_life":                [0.05, 0.10, 0.15, 0.70],
    "ml_recycling_manufacturing":    [0.05, 0.30, 0.20, 0.45],
    "ml_sustainability_product":     [0.30, 0.10, 0.10, 0.50],

    # Very broad — spans production & optimization
    "ml_manufacturing":              [0.10, 0.45, 0.40, 0.05],

    # Planning phase focus
    "ml_planning_production":        [0.75, 0.15, 0.10, 0.00],
    "ml_product_design":             [0.80, 0.15, 0.05, 0.00],
    "ml_plm":                        [0.40, 0.10, 0.15, 0.35],  # lifecycle both ends

    # Development / Production execution focus
    "ml_product_development":        [0.20, 0.60, 0.20, 0.00],
    "ml_defect_detection":           [0.10, 0.65, 0.25, 0.00],
    "ml_quality_control":            [0.05, 0.55, 0.40, 0.00],
    "ml_automation":                 [0.05, 0.70, 0.25, 0.00],
    "ml_robotics_production":        [0.05, 0.75, 0.20, 0.00],

    # Supply chain → planning weighted, but still operational relevance
    "ml_supply_chain":               [0.45, 0.35, 0.15, 0.05],

    # Optimization focused
    "ml_manufacturing_optimization": [0.05, 0.25, 0.70, 0.00],
    "ml_production_optimization":    [0.05, 0.25, 0.70, 0.00],
    "ml_process_optimization":       [0.05, 0.25, 0.70, 0.00],
    "ml_process_control":            [0.05, 0.20, 0.75, 0.00],
    "ml_process_modeling":           [0.10, 0.20, 0.70, 0.00],
    "ml_predictive_maintenance":     [0.05, 0.20, 0.60, 0.15],
    "ml_anomaly_detection_production":[0.05, 0.20, 0.70, 0.05],

    # Use / Reuse specific — RUL informs lifetime while still in operation
    "ml_rul":                        [0.05, 0.15, 0.30, 0.50],
}



def get_phase_prior(query_id):
    # Return a valid probability vector for the query
    prior = phase_priors.get(query_id)
    if prior is None:
        # Default weakly uniform prior if unknown query_id
        prior = np.array([0.25, 0.25, 0.25, 0.25], dtype=float)
    else:
        prior = np.array(prior, dtype=float)
        prior = prior / prior.sum()
    return prior

# %%
# Define embedding and similarity helpers (to be implemented with your chosen model)

model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")  # In use
light_model = SentenceTransformer("sentence-transformers/all-MiniLM-L12-v2")

def get_embedding(text):
    if not isinstance(text, str):
        text = ""
    emb = model.encode(
        text,
        show_progress_bar=False,
        convert_to_numpy=True,
        normalize_embeddings=True,
    )
    return emb

def cosine_similarity(a, b):
    # Compute cosine similarity between two 1D vectors
    denom = (np.linalg.norm(a) * np.linalg.norm(b))
    if denom == 0:
        return 0.0
    return float(np.dot(a, b) / denom)

# %%
# Precompute embeddings for all phase descriptions

phase_embeddings = []
for pid, ptext in zip(phase_ids, phase_texts):
    emb = get_embedding(ptext)
    phase_embeddings.append(emb)

phase_embeddings = np.vstack(phase_embeddings)
phase_embeddings.shape
# Out:
# (4, 768)

# %%
# Compute semantic phase scores for each abstract with progress bar

from tqdm import tqdm

sim_cols = ["sim_phase_1", "sim_phase_2", "sim_phase_3", "sim_phase_4"]

# Initialize columns
for col in sim_cols:
    df[col] = np.nan

batch_size = 512  # Adjust based on GPU memory

for start in tqdm(range(0, len(df), batch_size), desc="Embedding abstracts"):
    end = min(start + batch_size, len(df))
    batch = df.iloc[start:end]

    sims = []
    for text in batch["clean_abs"].astype(str).tolist():
        e_abs = get_embedding(text)
        sim_vec = [cosine_similarity(e_abs, pe) for pe in phase_embeddings]
        sims.append(sim_vec)

    sims = np.array(sims)
    exp_sims = np.exp(sims - sims.max(axis=1, keepdims=True))
    probs = exp_sims / exp_sims.sum(axis=1, keepdims=True)

    df.loc[batch.index, sim_cols] = probs

print("Semantic phase scores computed.")
df[sim_cols].head()
# Out:
# Embedding abstracts: 100%|██████████| 65/65 [09:32<00:00,  8.81s/it]
# Semantic phase scores computed.
#       sim_phase_1  sim_phase_2  sim_phase_3  sim_phase_4
# 3367     0.249607     0.227067     0.232375     0.290951
# 3390     0.258612     0.256324     0.235932     0.249132
# 3391     0.228577     0.229866     0.254541     0.287017
# 3392     0.231870     0.246742     0.260575     0.260813
# 3393     0.237168     0.228828     0.262338     0.271666

# %%
# Combine query priors and semantic scores into final phase probabilities

alpha = 0.0 # Weight on priors (0=only semantics, 1=only priors)

final_cols = ["phase_p1", "phase_p2", "phase_p3", "phase_p4"]
df[final_cols] = np.nan

primary_labels = []
secondary_labels = []

for idx, row in df.iterrows():
    prior = get_phase_prior(row["query_id"])
    sem = row[sim_cols].values.astype(float)

    # Safety check for NaN
    if np.any(~np.isfinite(sem)):
        sem = np.ones(4) / 4.0

    combined = alpha * prior + (1 - alpha) * sem
    combined = combined / combined.sum()

    df.loc[idx, final_cols] = combined

    # Determine primary and secondary phases
    order = np.argsort(-combined)  # descending
    primary = order[0] + 1  # 1-based phase index
    secondary = order[1] + 1

    primary_labels.append(primary)
    secondary_labels.append(secondary)

df["primary_phase"] = primary_labels
df["secondary_phase"] = secondary_labels

print("Final phase probabilities and labels added.")
df[["query_id", "primary_phase", "secondary_phase"] + final_cols].head()
# Out:
# Final phase probabilities and labels added.
#             query_id  primary_phase  secondary_phase  phase_p1  phase_p2  \
# 3367  ml_end_of_life              4                1  0.249607  0.227067
# 3390  ml_end_of_life              1                2  0.258612  0.256324
# 3391  ml_end_of_life              4                3  0.228577  0.229866
# 3392  ml_end_of_life              4                3  0.231870  0.246742
# 3393  ml_end_of_life              4                3  0.237168  0.228828
#
#       phase_p3  phase_p4
# 3367  0.232375  0.290951
# 3390  0.235932  0.249132
# 3391  0.254541  0.287017
# 3392  0.260575  0.260813
# 3393  0.262338  0.271666

# %%
# Save extended dataset with phase information

out_path = save_path / "abstracts_with_phases.csv"
df.to_csv(out_path, index=False)
print(f"Saved dataset with phases to: {out_path}")
# Out:
# Saved dataset with phases to: ../../data/processed/abstracts/semantic_analysis_ext_desc/abstracts_with_phases.csv

# %%
# Save dataset with just one phase-column

# Compute single phase column based on highest probability
phase_cols = ["phase_p1", "phase_p2", "phase_p3", "phase_p4"]
df["phase"] = df[phase_cols].idxmax(axis=1).str.extract('(\d+)').astype(int)

# Drop old phase columns
df_min = df.drop(columns=phase_cols + [
    "sim_phase_1", "sim_phase_2", "sim_phase_3", "sim_phase_4",
    "primary_phase", "secondary_phase"
])

# Save minimal dataset
out_path_min = save_path / "abstracts_min_phases.csv"
df_min.to_csv(out_path_min, index=False)

print(f"Saved minimal dataset with single phase column to: {out_path_min}")
# Out:
# Saved minimal dataset with single phase column to: ../../data/processed/abstracts/semantic_analysis_ext_desc/abstracts_min_phases.csv

# %%
# Plot primary phase distribution

phase_counts = df["primary_phase"].value_counts().sort_index()
print(phase_counts)

plt.figure(figsize=(6,4))
phase_counts.plot(kind="bar")
plt.xlabel("Primary phase")
plt.ylabel("Count")
plt.title("Primary phase distribution")
plt.tight_layout()
plt.show()
# Out:
# primary_phase
# 1     2672
# 2     8894
# 3    15578
# 4     5986
# Name: count, dtype: int64

# %%
# Inspect phase distribution per query_id

phase_query_ct = pd.crosstab(df["query_id"], df["primary_phase"], normalize="index")
phase_query_ct = phase_query_ct.rename(columns=lambda x: f"phase_{x}")

phase_query_ct.head(25)
# Out:
# primary_phase                     phase_1   phase_2   phase_3   phase_4
# query_id
# ml_anomaly_detection_production  0.003279  0.039344  0.862295  0.095082
# ml_automation                    0.024777  0.457879  0.404361  0.112983
# ml_defect_detection              0.000000  0.383607  0.375410  0.240984
# ml_disassembly                   0.040590  0.324723  0.409594  0.225092
# ml_end_of_life                   0.098039  0.058824  0.019608  0.823529
# ml_inservice_monitoring          0.097561  0.097561  0.458537  0.346341
# ml_manufacturing                 0.044887  0.402850  0.410289  0.141975
# ml_manufacturing_optimization    0.075750  0.535017  0.333492  0.055741
# ml_planning_production           0.224178  0.187793  0.467136  0.120892
# ml_plm                           0.065502  0.192140  0.366812  0.375546
# ml_predictive_maintenance        0.007213  0.024918  0.614426  0.353443
# ml_process_control               0.025155  0.203299  0.711340  0.060206
# ml_process_modeling              0.101382  0.225806  0.631336  0.041475
# ml_process_optimization          0.013986  0.557692  0.400350  0.027972
# ml_product_design                0.221782  0.406931  0.179208  0.192079
# ml_product_development           0.235595  0.280410  0.253521  0.230474
# ml_production_optimization       0.175569  0.135070  0.598949  0.090412
# ml_quality_control               0.012048  0.343921  0.567360  0.076670
# ml_recycling_manufacturing       0.067961  0.359223  0.067961  0.504854
# ml_remanufacturing               0.040404  0.323232  0.111111  0.525253
# ml_robotics_production           0.033149  0.563536  0.237569  0.165746
# ml_rul                           0.000000  0.002847  0.362989  0.634164
# ml_supply_chain                  0.123055  0.205092  0.403112  0.268741
# ml_sustainability_product        0.173858  0.125635  0.299492  0.401015

# %%
# Show queries most dominated by each phase

for p in [1, 2, 3, 4]:
    col = f"phase_{p}"
    print(f"\nTop queries for {col}:")
    display(phase_query_ct[col].sort_values(ascending=False).head(10))
# Out:
# Top queries for phase_1:
# query_id
# ml_product_development           0.235595
# ml_planning_production           0.224178
# ml_product_design                0.221782
# ml_production_optimization       0.175569
# ml_sustainability_product        0.173858
# ml_supply_chain                  0.123055
# ml_process_modeling              0.101382
# ml_end_of_life                   0.098039
# ml_inservice_monitoring          0.097561
# ml_manufacturing_optimization    0.075750
# Name: phase_1, dtype: float64
# Top queries for phase_2:
# query_id
# ml_robotics_production           0.563536
# ml_process_optimization          0.557692
# ml_manufacturing_optimization    0.535017
# ml_automation                    0.457879
# ml_product_design                0.406931
# ml_manufacturing                 0.402850
# ml_defect_detection              0.383607
# ml_recycling_manufacturing       0.359223
# ml_quality_control               0.343921
# ml_disassembly                   0.324723
# Name: phase_2, dtype: float64
# Top queries for phase_3:
# query_id
# ml_anomaly_detection_production    0.862295
# ml_process_control                 0.711340
# ml_process_modeling                0.631336
# ml_predictive_maintenance          0.614426
# ml_production_optimization         0.598949
# ml_quality_control                 0.567360
# ml_planning_production             0.467136
# ml_inservice_monitoring            0.458537
# ml_manufacturing                   0.410289
# ml_disassembly                     0.409594
# Name: phase_3, dtype: float64
# Top queries for phase_4:
# query_id
# ml_end_of_life                0.823529
# ml_rul                        0.634164
# ml_remanufacturing            0.525253
# ml_recycling_manufacturing    0.504854
# ml_sustainability_product     0.401015
# ml_plm                        0.375546
# ml_predictive_maintenance     0.353443
# ml_inservice_monitoring       0.346341
# ml_supply_chain               0.268741
# ml_defect_detection           0.240984
# Name: phase_4, dtype: float64

# %%
# Compute confidence metrics for phase assignment

df["phase_max_prob"] = df[["phase_p1", "phase_p2", "phase_p3", "phase_p4"]].max(axis=1)

# Gap between primary and secondary phases
sorted_probs = np.sort(df[["phase_p1", "phase_p2", "phase_p3", "phase_p4"]].values, axis=1)
df["phase_margin"] = sorted_probs[:, -1] - sorted_probs[:, -2]

df[["primary_phase", "secondary_phase", "phase_max_prob", "phase_margin"]].describe()
# Out:
#        primary_phase  secondary_phase  phase_max_prob  phase_margin
# count   33130.000000     33130.000000    33130.000000  3.313000e+04
# mean        2.750921         2.709236        0.266489  1.153898e-02
# std         0.842454         1.055067        0.008674  9.649010e-03
# min         1.000000         1.000000        0.250300  3.331236e-07
# 25%         2.000000         2.000000        0.259865  4.033390e-03
# 50%         3.000000         3.000000        0.265175  9.146072e-03
# 75%         3.000000         4.000000        0.271789  1.670158e-02
# max         4.000000         4.000000        0.316873  7.458705e-02

# %%
# Plot distributions of confidence and margin

plt.figure(figsize=(6,4))
df["phase_max_prob"].hist(bins=20)
plt.xlabel("Max phase probability")
plt.ylabel("Count")
plt.title("Confidence in primary phase")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,4))
df["phase_margin"].hist(bins=20)
plt.xlabel("Primary vs secondary margin")
plt.ylabel("Count")
plt.title("Separation between top two phases")
plt.tight_layout()
plt.show()

# %%
# Inspect low-confidence samples

low_conf_mask = df["phase_max_prob"] < 0.5
print(f"Low-confidence abstracts (<0.5): {low_conf_mask.sum()}")

df_low_conf = df[low_conf_mask].sort_values("phase_max_prob").head(20)
df_low_conf[[
    "query_id",
    "doi",
    "primary_phase",
    "secondary_phase",
    "phase_p1",
    "phase_p2",
    "phase_p3",
    "phase_p4",
    "clean_abs"
]]
# Out:
# Low-confidence abstracts (<0.5): 33130
#                             query_id                                    doi  \
# 1519                   ml_automation             10.1557/s43577-023-00490-y
# 21343  ml_manufacturing_optimization           10.1007/978-3-031-96631-6_21
# 44555     ml_production_optimization            10.18687/LACCEI2022.1.1.616
# 17996               ml_manufacturing          10.1080/02580136.2021.1941652
# 51525      ml_sustainability_product         10.1016/j.biombioe.2024.107490
# 10477               ml_manufacturing             10.1007/s00170-024-14812-0
# 40092     ml_production_optimization                     10.3390/en18102523
# 22336  ml_manufacturing_optimization             10.1007/s12551-025-01360-4
# 17160               ml_manufacturing                      10.3390/pr9071157
# 39398     ml_production_optimization          10.1016/j.aquaeng.2025.102561
# 51577      ml_sustainability_product     10.1016/B978-0-443-15742-4.00027-2
# 17077               ml_manufacturing                      10.3390/pr9081342
# 40023     ml_production_optimization                      10.14419/xk2n4x45
# 25588         ml_planning_production  10.1109/RusAutoCon65989.2025.11177381
# 18927               ml_manufacturing              10.1007/978-3-030-36375-8
# 45298     ml_production_optimization                      10.2118/206174-MS
# 38749         ml_product_development              10.3389/fpubh.2022.862432
# 5884                ml_manufacturing                     10.1002/cnl2.70017
# 27551                         ml_plm             10.1038/s41598-025-08510-4
# 39074         ml_product_development                      10.1159/000352012
#
#        primary_phase  secondary_phase  phase_p1  phase_p2  phase_p3  phase_p4  \
# 1519               2                4  0.249257  0.250300  0.250151  0.250292
# 21343              1                3  0.250432  0.250224  0.250274  0.249070
# 44555              4                1  0.250438  0.249131  0.249929  0.250501
# 17996              2                1  0.250410  0.250506  0.248922  0.250162
# 51525              1                4  0.250578  0.249479  0.249865  0.250078
# 10477              2                1  0.250661  0.250670  0.248385  0.250283
# 40092              4                2  0.249451  0.250039  0.249791  0.250720
# 22336              2                4  0.249678  0.250811  0.249137  0.250374
# 17160              1                3  0.250833  0.249540  0.250148  0.249479
# 39398              4                3  0.248402  0.250152  0.250559  0.250888
# 51577              3                1  0.250863  0.247601  0.250911  0.250626
# 17077              1                4  0.250959  0.249151  0.249567  0.250322
# 40023              4                2  0.249069  0.250144  0.249810  0.250978
# 25588              4                1  0.250655  0.248514  0.249806  0.251025
# 18927              3                2  0.250009  0.250700  0.251035  0.248256
# 45298              1                2  0.251046  0.249737  0.249668  0.249548
# 38749              4                3  0.247494  0.250372  0.251055  0.251080
# 5884               4                2  0.249622  0.249770  0.249526  0.251082
# 27551              2                3  0.249768  0.251086  0.249985  0.249161
# 39074              1                4  0.251126  0.248651  0.249975  0.250247
#
#                                                clean_abs
# 1519   Low-dimensional hybrid perovskites combine the...
# 21343  Artificial intelligence (AI) fundamentally tra...
# 44555  All rights reserved.The problem addressed the ...
# 17996  The Fourth Industrial Revolution (4IR) and acc...
# 51525  In this study, activated carbon derived from s...
# 10477  , part of Springer Nature 2024.In this article...
# 40092  Unconventional reservoirs are characterized by...
# 22336  The applications of immobilized enzymes in ind...
# 17160  Licensee MDPI, Basel, Switzerland.Suppliers ar...
# 39398  This study extends our previous work on using ...
# 51577  All rights are reserved, including those for t...
# 17077  Licensee MDPI, Basel, Switzerland.Researchers ...
# 40023  “Every End Marks a New Beginning,” Cycle Conti...
# 25588  This study addresses the urgent need to modern...
# 18927  This book offers practical guidelines on creat...
# 45298  Copyright © 2021, Society of Petroleum Enginee...
# 38749  Copyright © 2022 Pernencar, Saboia and Dias.Mo...
# 5884   Carbon Neutralization published by Wenzhou Uni...
# 27551  Clathrin is a key cytoplasmic protein that ser...
# 39074  Karger AG, Basel.This article summarizes the w...

# %%
# Aggregate mean phase probabilities per query_id

phase_prob_cols = ["phase_p1", "phase_p2", "phase_p3", "phase_p4"]
query_phase_means = df.groupby("query_id")[phase_prob_cols].mean()

query_phase_means.head()
# Out:
#                                  phase_p1  phase_p2  phase_p3  phase_p4
# query_id
# ml_anomaly_detection_production  0.228397  0.245166  0.272307  0.254130
# ml_automation                    0.235754  0.258639  0.257367  0.248239
# ml_defect_detection              0.227902  0.258314  0.259038  0.254746
# ml_disassembly                   0.242353  0.252108  0.253692  0.251847
# ml_end_of_life                   0.241600  0.246381  0.242079  0.269939

# %%
# Show queries with highest mean probability for each phase

for i, col in enumerate(phase_prob_cols, start=1):
    print(f"\nTop queries by mean {col}:")
    display(query_phase_means[col].sort_values(ascending=False).head(10))
# Out:
# Top queries by mean phase_p1:
# query_id
# ml_product_development           0.251186
# ml_product_design                0.250852
# ml_planning_production           0.248855
# ml_sustainability_product        0.247839
# ml_production_optimization       0.247351
# ml_supply_chain                  0.244733
# ml_plm                           0.244136
# ml_manufacturing_optimization    0.243666
# ml_process_modeling              0.243050
# ml_disassembly                   0.242353
# Name: phase_p1, dtype: float64
# Top queries by mean phase_p2:
# query_id
# ml_process_optimization          0.261645
# ml_robotics_production           0.259555
# ml_manufacturing_optimization    0.259186
# ml_automation                    0.258639
# ml_defect_detection              0.258314
# ml_quality_control               0.257929
# ml_manufacturing                 0.255946
# ml_product_design                0.255768
# ml_recycling_manufacturing       0.255299
# ml_remanufacturing               0.255026
# Name: phase_p2, dtype: float64
# Top queries by mean phase_p3:
# query_id
# ml_anomaly_detection_production    0.272307
# ml_predictive_maintenance          0.268240
# ml_process_control                 0.267780
# ml_rul                             0.266459
# ml_quality_control                 0.262664
# ml_process_modeling                0.262420
# ml_defect_detection                0.259038
# ml_process_optimization            0.258550
# ml_production_optimization         0.258237
# ml_inservice_monitoring            0.257770
# Name: phase_p3, dtype: float64
# Top queries by mean phase_p4:
# query_id
# ml_rul                             0.271348
# ml_end_of_life                     0.269939
# ml_predictive_maintenance          0.263464
# ml_remanufacturing                 0.262792
# ml_recycling_manufacturing         0.258260
# ml_inservice_monitoring            0.255814
# ml_defect_detection                0.254746
# ml_sustainability_product          0.254186
# ml_anomaly_detection_production    0.254130
# ml_plm                             0.253237
# Name: phase_p4, dtype: float64

# %%
# Plot heatmap of mean phase probabilities per query_id

import seaborn as sns  # if you are OK adding seaborn

plt.figure(figsize=(10, len(query_phase_means) * 0.3))
sns.heatmap(
    query_phase_means[phase_prob_cols],
    annot=False,
    cmap="viridis",
    cbar=True
)
plt.xlabel("Phase")
plt.ylabel("Query ID")
plt.title("Mean phase probabilities per query")
plt.tight_layout()
plt.show()

# %%
# Show the most confident abstracts for each phase (primary_phase)
cols_show = [
    "query_id", "doi", "primary_phase", "phase_max_prob", "phase_margin",
    "title", "clean_abs"
]

for p in [1, 2, 3, 4]:
    print(f"\nMost confident Phase {p} abstracts\n")
    
    df_phase = df[df["primary_phase"] == p]
    top_conf = df_phase.sort_values("phase_max_prob", ascending=False).head(5)
    
    display(top_conf[cols_show])
# Out:
# Most confident Phase 1 abstracts
#                          query_id                            doi  \
# 45999  ml_production_optimization      10.1007/s11625-017-0521-6
# 18664            ml_manufacturing               10.1002/smr.2247
# 37221           ml_product_design        10.1145/3640429.3640437
# 38248      ml_product_development      10.1016/j.dss.2025.114504
# 39070      ml_product_development  10.1016/j.jbusres.2014.02.015
#
#        primary_phase  phase_max_prob  phase_margin  \
# 45999              1        0.287704      0.046677
# 18664              1        0.284508      0.040305
# 37221              1        0.284409      0.030001
# 38248              1        0.281278      0.035778
# 39070              1        0.280978      0.024044
#
#                                                    title  \
# 45999  Assessment of mitigation strategies as tools f...
# 18664  A proposed framework for improved software req...
# 37221  Design Thinking Using Qualitative Data Analysi...
# 38248  An exploration and exploitation of value cocre...
# 39070                       Consideration-set heuristics
#
#                                                clean_abs
# 45999  Although the world understands the possible th...
# 18664  Software requirement engineering (SRE) is the ...
# 37221  Design Thinking is a human-centered approach t...
# 38248  V.Idea screening in collaborative crowdsourcin...
# 39070  Consumers often choose products by first formi...
# Most confident Phase 2 abstracts
#                      query_id                           doi  primary_phase  \
# 8025         ml_manufacturing     10.1007/978-3-031-78747-8              2
# 48589  ml_robotics_production  10.1007/978-3-030-62746-1_54              2
# 27104  ml_planning_production  10.1109/AI4I49448.2020.00015              2
# 18840        ml_manufacturing   10.1016/j.addma.2019.101003              2
# 48087  ml_robotics_production       10.54808/ICSIT2025.01.9              2
#
#        phase_max_prob  phase_margin  \
# 8025         0.297410      0.057167
# 48589        0.295679      0.045740
# 27104        0.293903      0.048682
# 18840        0.293718      0.047741
# 48087        0.292472      0.036108
#
#                                                    title  \
# 8025   CAD-based Programming for Design and Manufactu...
# 48589  Research and Development of Simulation System ...
# 27104  Towards a user-centered development process of...
# 18840  Building free-form thin shell parts using supp...
# 48087  Technology Enhanced Teaching for an Industry 4...
#
#                                                clean_abs
# 8025   This book offers a thorough examination of CAD...
# 48589  With the increasing demand for automation of p...
# 27104  The paradigm shift in manufacturing, the trans...
# 18840  V.Conventional material extrusion additive man...
# 48087  All Rights Reserved.The mission of engineering...
# Most confident Phase 3 abstracts
#                  query_id                            doi  primary_phase  \
# 18806    ml_manufacturing       10.1109/TII.2019.2940099              3
# 34552  ml_process_control  10.1080/00207543.2020.1812750              3
# 33545  ml_process_control               10.1002/qre.3356              3
# 35192  ml_process_control   10.1016/j.procir.2015.12.054              3
# 34276  ml_process_control  10.1080/00401706.2021.1929493              3
#
#        phase_max_prob  phase_margin  \
# 18806        0.316873      0.074587
# 34552        0.313953      0.069077
# 33545        0.311460      0.061475
# 35192        0.311106      0.073528
# 34276        0.310487      0.069121
#
#                                                    title  \
# 18806  Performance Supervised Fault Detection Schemes...
# 34552  Nonparametric monitoring of multivariate data ...
# 33545  A new multivariate extended homogeneously weig...
# 35192  Design Performance Analysis of a Self-Organizi...
# 34276  Transparent Sequential Learning for Statistica...
#
#                                                clean_abs
# 18806  This article addresses performance supervised ...
# 34552  Process monitoring of multivariate quality att...
# 33545  Statistical process monitoring (SPM) provides ...
# 35192  In industrial applications, the continuously g...
# 34276  Machine learning methods have been widely used...
# Most confident Phase 4 abstracts
#                         query_id                               doi  \
# 47896         ml_remanufacturing      10.1016/j.wasman.2014.11.024
# 14453           ml_manufacturing      10.1007/978-981-19-6383-4_30
# 49089                     ml_rul          10.1109/TIM.2025.3562242
# 51870  ml_sustainability_product  10.1109/ICASI60819.2024.10547722
# 48903                     ml_rul         10.1002/9781119933175.ch5
#
#        primary_phase  phase_max_prob  phase_margin  \
# 47896              4        0.300221      0.065357
# 14453              4        0.298301      0.053952
# 49089              4        0.296931      0.045549
# 51870              4        0.296125      0.050849
# 48903              4        0.295845      0.035482
#
#                                                    title  \
# 47896  An investigation of used electronics return fl...
# 14453  Experimental Analysis on Aging Evaluation of T...
# 49089  A Global Adversarial and Local Contrastive Tra...
# 51870  Remaining Value Estimation of Smartphones Appl...
# 48903  Unveiling the future: Residual life prediction...
#
#                                                clean_abs
# 47896  Consumers often have a tendency to store their...
# 14453  Transformer aging is the most significant feat...
# 49089  The transfer learning method can effectively m...
# 51870  The composition of increasing attention to sus...
# 48903  All rights reserved.This book chapter delves i...

# %%
# Show the least confident abstracts

for p in [1, 2, 3, 4]:
    print(f"\nLeast confident Phase {p} abstracts\n")
    df_phase = df[df["primary_phase"] == p]
    display(df_phase.sort_values("phase_max_prob").head(3)[cols_show])
# Out:
# Least confident Phase 1 abstracts
#                             query_id                             doi  \
# 21343  ml_manufacturing_optimization    10.1007/978-3-031-96631-6_21
# 51525      ml_sustainability_product  10.1016/j.biombioe.2024.107490
# 17160               ml_manufacturing               10.3390/pr9071157
#
#        primary_phase  phase_max_prob  phase_margin  \
# 21343              1        0.250432      0.000158
# 51525              1        0.250578      0.000500
# 17160              1        0.250833      0.000685
#
#                                                    title  \
# 21343  AI in the Pharmaceutical Industry: A Shift in ...
# 51525  Synthesis and characterization of novel lignoc...
# 17160  On the application of ARIMA and LSTM to predic...
#
#                                                clean_abs
# 21343  Artificial intelligence (AI) fundamentally tra...
# 51525  In this study, activated carbon derived from s...
# 17160  Licensee MDPI, Basel, Switzerland.Suppliers ar...
# Least confident Phase 2 abstracts
#                query_id                            doi  primary_phase  \
# 1519      ml_automation     10.1557/s43577-023-00490-y              2
# 17996  ml_manufacturing  10.1080/02580136.2021.1941652              2
# 10477  ml_manufacturing     10.1007/s00170-024-14812-0              2
#
#        phase_max_prob  phase_margin  \
# 1519         0.250300      0.000007
# 17996        0.250506      0.000096
# 10477        0.250670      0.000009
#
#                                                    title  \
# 1519   Toward self-organizing low-dimensional organic...
# 17996  Can Aristotelian virtue theory survive Fourth ...
# 10477  Correction to: Predicting tool life and sound ...
#
#                                                clean_abs
# 1519   Low-dimensional hybrid perovskites combine the...
# 17996  The Fourth Industrial Revolution (4IR) and acc...
# 10477  , part of Springer Nature 2024.In this article...
# Least confident Phase 3 abstracts
#                         query_id                                 doi  \
# 51577  ml_sustainability_product  10.1016/B978-0-443-15742-4.00027-2
# 18927           ml_manufacturing           10.1007/978-3-030-36375-8
# 15308           ml_manufacturing    10.1016/j.compstruct.2022.115475
#
#        primary_phase  phase_max_prob  phase_margin  \
# 51577              3        0.250911      0.000048
# 18927              3        0.251035      0.000336
# 15308              3        0.251227      0.000493
#
#                                                    title  \
# 51577                                           Biofuels
# 18927  Applying Data Science: How to Create Value wit...
# 15308  A novel integrated BPNN/SNN artificial neural ...
#
#                                                clean_abs
# 51577  All rights are reserved, including those for t...
# 18927  This book offers practical guidelines on creat...
# 15308  In this work, double integrated artificial neu...
# Least confident Phase 4 abstracts
#                          query_id                            doi  \
# 44555  ml_production_optimization    10.18687/LACCEI2022.1.1.616
# 40092  ml_production_optimization             10.3390/en18102523
# 39398  ml_production_optimization  10.1016/j.aquaeng.2025.102561
#
#        primary_phase  phase_max_prob  phase_margin  \
# 44555              4        0.250501      0.000063
# 40092              4        0.250720      0.000681
# 39398              4        0.250888      0.000329
#
#                                                    title  \
# 44555  Machine Learning using synthetic data in the s...
# 40092  Research on Shale Oil Well Productivity Predic...
# 39398  Energy optimization in large-scale recirculati...
#
#                                                clean_abs
# 44555  All rights reserved.The problem addressed the ...
# 40092  Unconventional reservoirs are characterized by...
# 39398  This study extends our previous work on using ...

# %% [markdown]
# ## Test semantic similarity robustness with artficial abstracts

# %%
def predict_phase_probs(text: str):
    # Compute embedding
    e_abs = get_embedding(text)
    
    # Raw cosine similarities
    sims = np.array([cosine_similarity(e_abs, pe) for pe in phase_embeddings])
    
    # Softmax
    exp_sims = np.exp(sims - np.max(sims))
    probs = exp_sims / np.sum(exp_sims)
    
    # Return both lists
    return probs.tolist(), sims.tolist()

# %%
# Extract fake example abstract for plc phase 1

file_path = "../../fake_data/abstract_plc_phase_1.txt"

with open(file_path, "r", encoding="utf-8") as f:
    plc_phase_1_txt = f.read()
    
pred_probs = predict_phase_probs(plc_phase_1_txt)

print("Phase probabilities for fake abstract - phase 1: \n")
print(pred_probs[0])

print("\n\nRaw cosine similarities: \n")
print(pred_probs[1])
# Out:
# Phase probabilities for fake abstract - phase 1:
#
# [0.2901752306809089, 0.2570448152390381, 0.21919327521656076, 0.23358667886349235]
#
#
# Raw cosine similarities:
#
# [0.6413259506225586, 0.5200914144515991, 0.3607948422431946, 0.4243941903114319]

# %%
phase_probs = pred_probs[0]
cosine_sims = pred_probs[1]

phases = ['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4']

# Plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(phases, phase_probs, color='skyblue')
axes[0].set_title("Phase Probabilities")
axes[0].set_ylabel("Probability")

axes[1].bar(phases, cosine_sims, color='salmon')
axes[1].set_title("Raw Cosine Similarities")
axes[1].set_ylabel("Similarity")

plt.tight_layout()
plt.show()

# %%
# Extract fake example abstract for plc phase 2

file_path = "../../fake_data/abstract_plc_phase_2.txt"

with open(file_path, "r", encoding="utf-8") as f:
    plc_phase_2_txt = f.read()
    
pred_probs = predict_phase_probs(plc_phase_2_txt)

print("Phase probabilities for fake abstract - phase 2: \n")
print(pred_probs[0])

print("\n\nRaw cosine similarities: \n")
print(pred_probs[1])
# Out:
# Phase probabilities for fake abstract - phase 2:
#
# [0.22797745456768864, 0.2854230494962176, 0.2567494092781801, 0.2298500866579137]
#
#
# Raw cosine similarities:
#
# [0.31183505058288574, 0.5365607738494873, 0.43068885803222656, 0.3200156092643738]

# %%
phase_probs = pred_probs[0]
cosine_sims = pred_probs[1]

phases = ['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4']

# Plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(phases, phase_probs, color='skyblue')
axes[0].set_title("Phase Probabilities")
axes[0].set_ylabel("Probability")

axes[1].bar(phases, cosine_sims, color='salmon')
axes[1].set_title("Raw Cosine Similarities")
axes[1].set_ylabel("Similarity")

plt.tight_layout()
plt.show()

# %%
# Extract fake example abstract for plc phase 3

file_path = "../../fake_data/abstract_plc_phase_3.txt"

with open(file_path, "r", encoding="utf-8") as f:
    plc_phase_3_txt = f.read()
    
pred_probs = predict_phase_probs(plc_phase_3_txt)

print("Phase probabilities for fake abstract - phase 3: \n")
print(pred_probs[0])

print("\n\nRaw cosine similarities: \n")
print(pred_probs[1])
# Out:
# Phase probabilities for fake abstract - phase 3:
#
# [0.20457750782639691, 0.2450216603065836, 0.282898850721894, 0.26750198114512547]
#
#
# Raw cosine similarities:
#
# [0.1809091717004776, 0.36130887269973755, 0.5050516724586487, 0.4490892291069031]

# %%
phase_probs = pred_probs[0]
cosine_sims = pred_probs[1]

phases = ['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4']

# Plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(phases, phase_probs, color='skyblue')
axes[0].set_title("Phase Probabilities")
axes[0].set_ylabel("Probability")

axes[1].bar(phases, cosine_sims, color='salmon')
axes[1].set_title("Raw Cosine Similarities")
axes[1].set_ylabel("Similarity")

plt.tight_layout()
plt.show()

# %%
# Extract fake example abstract for plc phase 4

file_path = "../../fake_data/abstract_plc_phase_4.txt"

with open(file_path, "r", encoding="utf-8") as f:
    plc_phase_4_txt = f.read()
    
pred_probs = predict_phase_probs(plc_phase_4_txt)

print("Phase probabilities for fake abstract - phase 4: \n")
print(pred_probs[0])

print("\n\nRaw cosine similarities: \n")
print(pred_probs[1])
# Out:
# Phase probabilities for fake abstract - phase 4:
#
# [0.21883249718734304, 0.24327309719098975, 0.2513928099031416, 0.28650159571852557]
#
#
# Raw cosine similarities:
#
# [0.29761525988578796, 0.40349334478378296, 0.4363253712654114, 0.5670527815818787]

# %%
phase_probs = pred_probs[0]
cosine_sims = pred_probs[1]

phases = ['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4']

# Plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(phases, phase_probs, color='skyblue')
axes[0].set_title("Phase Probabilities")
axes[0].set_ylabel("Probability")

axes[1].bar(phases, cosine_sims, color='salmon')
axes[1].set_title("Raw Cosine Similarities")
axes[1].set_ylabel("Similarity")

plt.tight_layout()
plt.show()

# %%
# Extract fake example abstract for unclear plc phase

file_path = "../../fake_data/abstract_unclear_phase.txt"

with open(file_path, "r", encoding="utf-8") as f:
    plc_phase_unclear_txt = f.read()
    
pred_probs = predict_phase_probs(plc_phase_unclear_txt)

print("Phase probabilities for fake abstract - unclear: \n")
print(pred_probs[0])

print("\n\nRaw cosine similarities: \n")
print(pred_probs[1])
# Out:
# Phase probabilities for fake abstract - unclear:
#
# [0.23296345983029562, 0.24423662984411892, 0.25995398418070037, 0.26284592614488506]
#
#
# Raw cosine similarities:
#
# [0.433374285697937, 0.48063021898269653, 0.5429973006248474, 0.554060697555542]

# %%
phase_probs = pred_probs[0]
cosine_sims = pred_probs[1]

phases = ['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4']

# Plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(phases, phase_probs, color='skyblue')
axes[0].set_title("Phase Probabilities")
axes[0].set_ylabel("Probability")

axes[1].bar(phases, cosine_sims, color='salmon')
axes[1].set_title("Raw Cosine Similarities")
axes[1].set_ylabel("Similarity")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot embedded abstracts in 2D space with PCA

# %%
# Compute and store embeddings for all abstracts
df["embedding"] = df["clean_abs"].astype(str).apply(get_embedding)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 2
#       1 # Compute and store embeddings for all abstracts
# ----> 2 df["embedding"] = df["clean_abs"].astype(str).apply(get_embedding)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/pandas/core/series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/pandas/core/apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/pandas/core/apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[7], line 9, in get_embedding(text)
#       7 if not isinstance(text, str):
#       8     text = ""
# ----> 9 emb = model.encode(
#      10     text,
#      11     show_progress_bar=False,
#      12     convert_to_numpy=True,
#      13     normalize_embeddings=True,
#      14 )
#      15 return emb
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:261, in Transformer.forward(self, features, **kwargs)
#     238 """
#     239 Forward pass through the transformer model.
#     240
#    (...)    257         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     258 """
#     259 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 261 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     262 token_embeddings = outputs[0]
#     263 features["token_embeddings"] = token_embeddings
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/transformers/models/mpnet/modeling_mpnet.py:486, in MPNetModel.forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     484 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     485 embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 486 encoder_outputs = self.encoder(
#     487     embedding_output,
#     488     attention_mask=extended_attention_mask,
#     489     head_mask=head_mask,
#     490     output_attentions=output_attentions,
#     491     output_hidden_states=output_hidden_states,
#     492     return_dict=return_dict,
#     493 )
#     494 sequence_output = encoder_outputs[0]
#     495 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/transformers/models/mpnet/modeling_mpnet.py:331, in MPNetEncoder.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     321 def forward(
#     322     self,
#     323     hidden_states: torch.Tensor,
#    (...)    329     **kwargs,
#     330 ):
# --> 331     position_bias = self.compute_position_bias(hidden_states)
#     332     all_hidden_states = () if output_hidden_states else None
#     333     all_attentions = () if output_attentions else None
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/transformers/models/mpnet/modeling_mpnet.py:374, in MPNetEncoder.compute_position_bias(self, x, position_ids, num_buckets)
#     370     memory_position = torch.arange(klen, dtype=torch.long)[None, :]
#     372 relative_position = memory_position - context_position
# --> 374 rp_bucket = self.relative_position_bucket(relative_position, num_buckets=num_buckets)
#     375 rp_bucket = rp_bucket.to(x.device)
#     376 values = self.relative_attention_bias(rp_bucket)
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/transformers/models/mpnet/modeling_mpnet.py:387, in MPNetEncoder.relative_position_bucket(relative_position, num_buckets, max_distance)
#     384 n = -relative_position
#     386 num_buckets //= 2
# --> 387 ret += (n < 0).to(torch.long) * num_buckets
#     388 n = torch.abs(n)
#     390 max_exact = num_buckets // 2
#
# KeyboardInterrupt:

# %%
# Stack embeddings into a 2D array
X = np.vstack(df["embedding"].values)  # shape: (n_samples, emb_dim)

# %%
import umap

# Stack embeddings into matrix if not already done
X = np.vstack(df["embedding"].values)  # shape: (n_samples, emb_dim)

# Fit UMAP
reducer = umap.UMAP(
    n_neighbors=15,    # local structure
    min_dist=0.1,      # how tight clusters are
    metric="cosine",   # good for normalized sentence embeddings
    random_state=42,
)

X_umap = reducer.fit_transform(X)  # shape: (n_samples, 2)

df["emb_x"] = X_umap[:, 0]
df["emb_y"] = X_umap[:, 1]
# Out:
# /cluster/home/mbergst/.venvs/ml-catalogue/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 14
#       6 # Fit UMAP
#       7 reducer = umap.UMAP(
#       8     n_neighbors=15,    # local structure
#       9     min_dist=0.1,      # how tight clusters are
#      10     metric="cosine",   # good for normalized sentence embeddings
#      11     random_state=42,
#      12 )
# ---> 14 X_umap = reducer.fit_transform(X)  # shape: (n_samples, 2)
#      16 df["emb_x"] = X_umap[:, 0]
#      17 df["emb_y"] = X_umap[:, 1]
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/umap/umap_.py:2935, in UMAP.fit_transform(self, X, y, ensure_all_finite, **kwargs)
#    2897 def fit_transform(self, X, y=None, ensure_all_finite=True, **kwargs):
#    2898     """Fit X into an embedded space and return that transformed
#    2899     output.
#    2900
#    (...)   2933         Local radii of data points in the embedding (log-transformed).
#    2934     """
# -> 2935     self.fit(X, y, ensure_all_finite, **kwargs)
#    2936     if self.transform_mode == "embedding":
#    2937         if self.output_dens:
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/umap/umap_.py:2817, in UMAP.fit(self, X, y, ensure_all_finite, **kwargs)
#    2813 if self.transform_mode == "embedding":
#    2814     epochs = (
#    2815         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2816     )
# -> 2817     self.embedding_, aux_data = self._fit_embed_data(
#    2818         self._raw_data[index],
#    2819         epochs,
#    2820         init,
#    2821         random_state,  # JH why raw data?
#    2822         **kwargs,
#    2823     )
#    2825     if self.n_epochs_list is not None:
#    2826         if "embedding_list" not in aux_data:
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/umap/umap_.py:2872, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state, **kwargs)
#    2867 def _fit_embed_data(self, X, n_epochs, init, random_state, **kwargs):
#    2868     """A method wrapper for simplicial_set_embedding that can be
#    2869     replaced by subclasses. Arbitrary keyword arguments can be passed
#    2870     through .fit() and .fit_transform().
#    2871     """
# -> 2872     return simplicial_set_embedding(
#    2873         X,
#    2874         self.graph_,
#    2875         self.n_components,
#    2876         self._initial_alpha,
#    2877         self._a,
#    2878         self._b,
#    2879         self.repulsion_strength,
#    2880         self.negative_sample_rate,
#    2881         n_epochs,
#    2882         init,
#    2883         random_state,
#    2884         self._input_distance_func,
#    2885         self._metric_kwds,
#    2886         self.densmap,
#    2887         self._densmap_kwds,
#    2888         self.output_dens,
#    2889         self._output_distance_func,
#    2890         self._output_metric_kwds,
#    2891         self.output_metric in ("euclidean", "l2"),
#    2892         self.random_state is None,
#    2893         self.verbose,
#    2894         tqdm_kwds=self.tqdm_kwds,
#    2895     )
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/umap/umap_.py:1195, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1188 embedding = (
#    1189     10.0
#    1190     * (embedding - np.min(embedding, 0))
#    1191     / (np.max(embedding, 0) - np.min(embedding, 0))
#    1192 ).astype(np.float32, order="C")
#    1194 if euclidean_output:
# -> 1195     embedding = optimize_layout_euclidean(
#    1196         embedding,
#    1197         embedding,
#    1198         head,
#    1199         tail,
#    1200         n_epochs,
#    1201         n_vertices,
#    1202         epochs_per_sample,
#    1203         a,
#    1204         b,
#    1205         rng_state,
#    1206         gamma,
#    1207         initial_alpha,
#    1208         negative_sample_rate,
#    1209         parallel=parallel,
#    1210         verbose=verbose,
#    1211         densmap=densmap,
#    1212         densmap_kwds=densmap_kwds,
#    1213         tqdm_kwds=tqdm_kwds,
#    1214         move_other=True,
#    1215     )
#    1216 else:
#    1217     embedding = optimize_layout_generic(
#    1218         embedding,
#    1219         embedding,
#    (...)   1235         move_other=True,
#    1236     )
#
# File ~/.venvs/ml-catalogue/lib/python3.11/site-packages/umap/layouts.py:401, in optimize_layout_euclidean(head_embedding, tail_embedding, head, tail, n_epochs, n_vertices, epochs_per_sample, a, b, rng_state, gamma, initial_alpha, negative_sample_rate, parallel, verbose, densmap, densmap_kwds, tqdm_kwds, move_other)
#     398     dens_re_mean = 0
#     399     dens_re_cov = 0
# --> 401 optimize_fn(
#     402     head_embedding,
#     403     tail_embedding,
#     404     head,
#     405     tail,
#     406     n_vertices,
#     407     epochs_per_sample,
#     408     a,
#     409     b,
#     410     rng_state_per_sample,
#     411     gamma,
#     412     dim,
#     413     move_other,
#     414     alpha,
#     415     epochs_per_negative_sample,
#     416     epoch_of_next_negative_sample,
#     417     epoch_of_next_sample,
#     418     n,
#     419     densmap_flag,
#     420     dens_phi_sum,
#     421     dens_re_sum,
#     422     dens_re_cov,
#     423     dens_re_std,
#     424     dens_re_mean,
#     425     dens_lambda,
#     426     dens_R,
#     427     dens_mu,
#     428     dens_mu_tot,
#     429 )
#     431 alpha = initial_alpha * (1.0 - (float(n) / float(n_epochs)))
#     433 if verbose and n % int(n_epochs / 10) == 0:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(8, 6))

for p in [1, 2, 3, 4]:
    mask = df["primary_phase"] == p
    plt.scatter(
        df.loc[mask, "emb_x"],
        df.loc[mask, "emb_y"],
        label=f"Phase {p}",
        alpha=0.6,
        s=15,
    )

plt.xlabel("UMAP1")
plt.ylabel("UMAP2")
plt.legend()
plt.title("Abstracts in embedding space (UMAP)")
plt.tight_layout()
plt.show()
